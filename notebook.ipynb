# %%
import pandas as pd
print("Pandas version:", pd.__version__)
# Out:
# Pandas version: 3.0.0

# %%
git add .
git commit -m "Initial workspace setup with venv and Jupyter"
# Out:
#   Cell In[1], line 1
#     git add .
#         ^
# SyntaxError: invalid syntax

# %%
cd D:\analysis_workspace
# Out:
#   Cell In[2], line 1
#     cd D:\analysis_workspace
#        ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
print("Pandas working!", pd.__version__)
# Out:
# Pandas working! 3.0.0

# %%
import pandas as pd
print("Pandas working!", pd.__version__)
# Out:
# Pandas working! 3.0.0

# %%
git add .
git commit -m "Initial workspace setup"
# Out:
#   Cell In[3], line 1
#     git add .
#         ^
# SyntaxError: invalid syntax
